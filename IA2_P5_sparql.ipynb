# %% [markdown]
# # Práctica 3: Representación del conocimiento
#
# __Fecha de entrega: 8 de mayo de 2022__
#
# El objetivo de esta práctica es aplicar los conceptos teóricos vistos en clase en el módulo de Representación de conocimiento. La práctica consta de un único notebook que se entregará en la tarea de entrega habilitada en el Campus  Virtual.
#
# Cada consulta debe contener breves comentarios que expliquen cada tripleta. __No se valorarán consultas sin explicaciones__.

# %% [markdown]
# __Número de grupo: 10__
#
# __Nombres de los estudiantes: Adrián Sanjuan Espejo, Rubén Gómez Blanco y Adrián Pérez Peinador__

# %% [markdown]
# ## Consultas SPARQL sobre Wikidata.
#
# En esta práctica vamos a usar el [punto de acceso SPARQL](https://query.wikidata.org/) de Wikidata para contestar las preguntas que se formulan a continuación. Cada pregunta debe ser respondida realizando una única consulta SPARQL. Para cada una de las entidades recuperadas se mostrará __tanto su identificador como su etiqueta__ (nombre de la entidad en lenguaje natural).
#
# Para cada una de las preguntas debes mostrar tanto la consulta como la respuesta obtenida. Si lo consideras necesario, puedes añadir celdas adicionales en formato _Markdown_ para explicar decisiones que hayas tomado al crear la consulta o cualquier otro dato que consideres interesante.
#
# Para resolver estas consultas puedes usar __dos recursos que te recomendamos consultar__ son:
#
# - [Este tutorial de SPARQL](https://www.wikidata.org/wiki/Wikidata:SPARQL_tutorial).
# - [Esta recopilación de ejemplos](https://www.wikidata.org/wiki/Wikidata:SPARQL_query_service/queries/examples)

# %%
import sys

# !{sys.executable} -m pip install wdsparql
# Out:
# Requirement already satisfied: wdsparql in c:\users\app2m\anaconda3\lib\site-packages (0.0.3)
# Requirement already satisfied: pandas>=1.1 in c:\users\app2m\anaconda3\lib\site-packages (from wdsparql) (1.2.4)
# Requirement already satisfied: ipython>=7.0.0 in c:\users\app2m\anaconda3\lib\site-packages (from wdsparql) (7.22.0)
# Requirement already satisfied: requests>=2.20 in c:\users\app2m\anaconda3\lib\site-packages (from wdsparql) (2.25.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\app2m\anaconda3\lib\site-packages (from ipython>=7.0.0->wdsparql) (0.17.2)
# Requirement already satisfied: traitlets>=4.2 in c:\users\app2m\anaconda3\lib\site-packages (from ipython>=7.0.0->wdsparql) (5.0.5)
# Requirement already satisfied: colorama in c:\users\app2m\anaconda3\lib\site-packages (from ipython>=7.0.0->wdsparql) (0.4.4)
# Requirement already satisfied: pygments in c:\users\app2m\anaconda3\lib\site-packages (from ipython>=7.0.0->wdsparql) (2.8.1)
# Requirement already satisfied: setuptools>=18.5 in c:\users\app2m\anaconda3\lib\site-packages (from ipython>=7.0.0->wdsparql) (52.0.0.post20210125)
# Requirement already satisfied: backcall in c:\users\app2m\anaconda3\lib\site-packages (from ipython>=7.0.0->wdsparql) (0.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\app2m\anaconda3\lib\site-packages (from ipython>=7.0.0->wdsparql) (3.0.17)
# Requirement already satisfied: pickleshare in c:\users\app2m\anaconda3\lib\site-packages (from ipython>=7.0.0->wdsparql) (0.7.5)
# Requirement already satisfied: decorator in c:\users\app2m\anaconda3\lib\site-packages (from ipython>=7.0.0->wdsparql) (5.0.6)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in c:\users\app2m\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=7.0.0->wdsparql) (0.7.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\app2m\anaconda3\lib\site-packages (from pandas>=1.1->wdsparql) (2.8.1)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\app2m\anaconda3\lib\site-packages (from pandas>=1.1->wdsparql) (1.20.1)
# Requirement already satisfied: pytz>=2017.3 in c:\users\app2m\anaconda3\lib\site-packages (from pandas>=1.1->wdsparql) (2021.1)
# Requirement already satisfied: wcwidth in c:\users\app2m\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.0.0->wdsparql) (0.2.5)
# Requirement already satisfied: six>=1.5 in c:\users\app2m\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas>=1.1->wdsparql) (1.15.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\app2m\anaconda3\lib\site-packages (from requests>=2.20->wdsparql) (2020.12.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\app2m\anaconda3\lib\site-packages (from requests>=2.20->wdsparql) (1.26.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\app2m\anaconda3\lib\site-packages (from requests>=2.20->wdsparql) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\app2m\anaconda3\lib\site-packages (from requests>=2.20->wdsparql) (4.0.0)
# Requirement already satisfied: ipython-genutils in c:\users\app2m\anaconda3\lib\site-packages (from traitlets>=4.2->ipython>=7.0.0->wdsparql) (0.2.0)

# %%
# %load_ext autoreload
# %load_ext wdsparql
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# The wdsparql extension is already loaded. To reload it, use:
#   %reload_ext wdsparql

# %% [markdown]
# ### Ejemplo
#
# Recuperar todas las instancias directas de la clase [Cabra (Q2934)](https://www.wikidata.org/wiki/Q2934) que aparecen en la base de conocimiento.

# %%
# %%wdsparql
# SELECT ?item ?itemLabel
# WHERE
# {
#   ?item wdt:P31 wd:Q2934.  # instancias directas de la clase Cabra
#   SERVICE wikibase:label { bd:serviceParam wikibase:language "en". }
# }
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>item</th>
#       <th>itemLabel</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td><a href="http://www.wikidata.org/entity/Q151345" target="_blank">http://www.wikidata.org/entity/Q151345</a></td>
#       <td>Billygoat Hennes</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td><a href="http://www.wikidata.org/entity/Q3569037" target="_blank">http://www.wikidata.org/entity/Q3569037</a></td>
#       <td>William Windsor</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td><a href="http://www.wikidata.org/entity/Q23003932" target="_blank">http://www.wikidata.org/entity/Q23003932</a></td>
#       <td>His Whiskers</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td><a href="http://www.wikidata.org/entity/Q24287064" target="_blank">http://www.wikidata.org/entity/Q24287064</a></td>
#       <td>Taffy</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td><a href="http://www.wikidata.org/entity/Q41239734" target="_blank">http://www.wikidata.org/entity/Q41239734</a></td>
#       <td>Lance Corporal Shenkin III</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td><a href="http://www.wikidata.org/entity/Q41240892" target="_blank">http://www.wikidata.org/entity/Q41240892</a></td>
#       <td>Lance Corporal Shenkin II</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td><a href="http://www.wikidata.org/entity/Q41241416" target="_blank">http://www.wikidata.org/entity/Q41241416</a></td>
#       <td>Lance Corporal Shenkin I</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ### Consulta 1
#
# [Isaac Asimov (Q34981)](https://www.wikidata.org/wiki/Q34981) fue un escritor y profesor de bioquímica en la Universidad de Boston conocido por ser un prolífico autor de obras de ciencia ficción, historia y divulgación científica.
#
# Vamos a comenzar por averiguar su fecha y lugar de nacimiento (localidad y país al que pertenece la localidad en la actualidad).

# %%
# %%wdsparql
# SELECT  ?nacimiento ?nacimientoLabel ?lugar ?lugarLabel ?pais ?paisLabel
# WHERE
# {
#   wd:Q34981 wdt:P569 ?nacimiento. # Isaac Asimov -> Fecha de nacimiento
#   wd:Q34981 wdt:P19 ?lugar.       # Isaac Asimov -> Lugar de nacimiento
#   ?lugar wdt:P17 ?pais            # ?lugar -> pais -> ?pais
#   SERVICE wikibase:label { bd:serviceParam wikibase:language "en". }
#
# }
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>nacimiento</th>
#       <th>nacimientoLabel</th>
#       <th>lugar</th>
#       <th>lugarLabel</th>
#       <th>pais</th>
#       <th>paisLabel</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1920-01-02T00:00:00Z</td>
#       <td>1920-01-02T00:00:00Z</td>
#       <td><a href="http://www.wikidata.org/entity/Q1010621" target="_blank">http://www.wikidata.org/entity/Q1010621</a></td>
#       <td>Petrovichi</td>
#       <td><a href="http://www.wikidata.org/entity/Q159" target="_blank">http://www.wikidata.org/entity/Q159</a></td>
#       <td>Russia</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ### Consulta 2
#
# A continuación vamos a averiguar todas las distintas profesiones (ocupaciones) que se le reconocen en la base de conocimiento. Queremos obtener los resultados ordenados alfabéticamente por el nombre de la profesión.

# %%
# %%wdsparql
# SELECT ?profesion ?profesionLabel
# WHERE
# {
#   wd:Q34981 wdt:P106 ?profesion. #Isaac Asimov -> ocupación
#
#   SERVICE wikibase:label { bd:serviceParam wikibase:language "en". }
#
# }
# ORDER BY ?profesionLabel # Ordenar alfabéticamente por profesión
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>profesion</th>
#       <th>profesionLabel</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td><a href="http://www.wikidata.org/entity/Q18814623" target="_blank">http://www.wikidata.org/entity/Q18814623</a></td>
#       <td>autobiographer</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td><a href="http://www.wikidata.org/entity/Q2919046" target="_blank">http://www.wikidata.org/entity/Q2919046</a></td>
#       <td>biochemist</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td><a href="http://www.wikidata.org/entity/Q1930187" target="_blank">http://www.wikidata.org/entity/Q1930187</a></td>
#       <td>journalist</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td><a href="http://www.wikidata.org/entity/Q15980158" target="_blank">http://www.wikidata.org/entity/Q15980158</a></td>
#       <td>non-fiction writer</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td><a href="http://www.wikidata.org/entity/Q6625963" target="_blank">http://www.wikidata.org/entity/Q6625963</a></td>
#       <td>novelist</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td><a href="http://www.wikidata.org/entity/Q12144794" target="_blank">http://www.wikidata.org/entity/Q12144794</a></td>
#       <td>prosaist</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td><a href="http://www.wikidata.org/entity/Q18844224" target="_blank">http://www.wikidata.org/entity/Q18844224</a></td>
#       <td>science fiction writer</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td><a href="http://www.wikidata.org/entity/Q3745071" target="_blank">http://www.wikidata.org/entity/Q3745071</a></td>
#       <td>science writer</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td><a href="http://www.wikidata.org/entity/Q901" target="_blank">http://www.wikidata.org/entity/Q901</a></td>
#       <td>scientist</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td><a href="http://www.wikidata.org/entity/Q28389" target="_blank">http://www.wikidata.org/entity/Q28389</a></td>
#       <td>screenwriter</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td><a href="http://www.wikidata.org/entity/Q1622272" target="_blank">http://www.wikidata.org/entity/Q1622272</a></td>
#       <td>university teacher</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td><a href="http://www.wikidata.org/entity/Q36180" target="_blank">http://www.wikidata.org/entity/Q36180</a></td>
#       <td>writer</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ### Consulta 3
#
# De todas esas profesiones, ¿cuáles corresponden con subtipos de [Escritor (Q36180)](https://www.wikidata.org/wiki/Q36180)? Ten en cuenta que la jerarquía de tipos de escritores puede ser muy sofisticada.
#
# Puede que [esto](https://www.wikidata.org/wiki/Wikidata:SPARQL_tutorial#Property_paths) te resulte útil.

# %%
# %%wdsparql
# SELECT ?profesion ?profesionLabel
# WHERE
# {
#   wd:Q34981 wdt:P106 ?profesion. # Isaac Asimov -> ocupación
#   ?profesion wdt:P279+ wd:Q36180. # Subclases de escritor y subclases de susbclases de escritor recurrentemente
#   SERVICE wikibase:label { bd:serviceParam wikibase:language "en". }
# }
# ORDER BY ?profesionLabel # Ordenar alfabéticamente por profesión
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>profesion</th>
#       <th>profesionLabel</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td><a href="http://www.wikidata.org/entity/Q18814623" target="_blank">http://www.wikidata.org/entity/Q18814623</a></td>
#       <td>autobiographer</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td><a href="http://www.wikidata.org/entity/Q2919046" target="_blank">http://www.wikidata.org/entity/Q2919046</a></td>
#       <td>biochemist</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td><a href="http://www.wikidata.org/entity/Q1930187" target="_blank">http://www.wikidata.org/entity/Q1930187</a></td>
#       <td>journalist</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td><a href="http://www.wikidata.org/entity/Q15980158" target="_blank">http://www.wikidata.org/entity/Q15980158</a></td>
#       <td>non-fiction writer</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td><a href="http://www.wikidata.org/entity/Q6625963" target="_blank">http://www.wikidata.org/entity/Q6625963</a></td>
#       <td>novelist</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td><a href="http://www.wikidata.org/entity/Q12144794" target="_blank">http://www.wikidata.org/entity/Q12144794</a></td>
#       <td>prosaist</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td><a href="http://www.wikidata.org/entity/Q18844224" target="_blank">http://www.wikidata.org/entity/Q18844224</a></td>
#       <td>science fiction writer</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td><a href="http://www.wikidata.org/entity/Q3745071" target="_blank">http://www.wikidata.org/entity/Q3745071</a></td>
#       <td>science writer</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td><a href="http://www.wikidata.org/entity/Q901" target="_blank">http://www.wikidata.org/entity/Q901</a></td>
#       <td>scientist</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td><a href="http://www.wikidata.org/entity/Q28389" target="_blank">http://www.wikidata.org/entity/Q28389</a></td>
#       <td>screenwriter</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td><a href="http://www.wikidata.org/entity/Q1622272" target="_blank">http://www.wikidata.org/entity/Q1622272</a></td>
#       <td>university teacher</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ### Consulta 4
#
# Asimov se casó más de una vez. Para cada uno de los matrimonios queremos conocer el nombre de la esposa y las fechas de inicio y finalización. Los resultados deben aparecer ordenados cronológicamente.
#
# Para resolver esta consulta necesitarás acceder a los cualificadores de nodos sentencia y necesitarás entender los prefijos que usa Wikidata. Puede que [esto](https://www.wikidata.org/wiki/Wikidata:SPARQL_tutorial#Qualifiers) te resulte útil.

# %%
# %%wdsparql
# SELECT ?nombreesposa ?nombreesposaLabel ?fechaini ?fechainiLabel ?fechafin ?fechafinLabel
# WHERE
# {
#   wd:Q34981 p:P26 ?esposa. #Isaac Asimov -> Esposas -> ?esposa
#   ?esposa ps:P26 ?nombreesposa. #esposa -> nombre_de_statement (nombre de la esposa)
#   ?esposa pq:P580 ?fechaini. #esposa -> Fecha inicio
#   ?esposa pq:P582 ?fechafin. #esposa -> Fecha fin
#   SERVICE wikibase:label { bd:serviceParam wikibase:language "en". }
#
# }
# ORDER BY ?fechaini #Ordenados por fecha inicio
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>nombreesposa</th>
#       <th>nombreesposaLabel</th>
#       <th>fechaini</th>
#       <th>fechainiLabel</th>
#       <th>fechafin</th>
#       <th>fechafinLabel</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td><a href="http://www.wikidata.org/entity/Q107693884" target="_blank">http://www.wikidata.org/entity/Q107693884</a></td>
#       <td>Gertrude Asimov</td>
#       <td>1942-07-26T00:00:00Z</td>
#       <td>1942-07-26T00:00:00Z</td>
#       <td>1973-01-01T00:00:00Z</td>
#       <td>1973-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td><a href="http://www.wikidata.org/entity/Q517435" target="_blank">http://www.wikidata.org/entity/Q517435</a></td>
#       <td>Janet Asimov</td>
#       <td>1973-01-01T00:00:00Z</td>
#       <td>1973-01-01T00:00:00Z</td>
#       <td>1992-01-01T00:00:00Z</td>
#       <td>1992-01-01T00:00:00Z</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ### Consulta 5
#
# Asimov recibió muchos premios a lo largo de su carrera. Queremos obtener la lista de premios y, para cada uno de ellos, la fecha y la obra por la que fue premiado (si están disponibles). Los resultados se deben mostrar ordenador por fecha.
#
# Puede que [esto](https://www.wikidata.org/wiki/Wikidata:SPARQL_tutorial#OPTIONAL) te resulte útil.

# %%
# %%wdsparql
# SELECT ?premio ?premioLabel ?fecha ?fechaLabel ?obra ?obraLabel
# WHERE
# {
#   wd:Q34981 p:P166 ?p. #Isaac Asimov -> Premios -> ?premio
#   ?p ps:P166 ?premio. #p -> nombre_de_p (nombre del premio)
#   ?p pq:P585 ?fecha. #p -> fecha
#   OPTIONAL{?p pq:P1686 ?obra. } #p -> obra (si la hay)
#   SERVICE wikibase:label { bd:serviceParam wikibase:language "en". }
#
# }
# ORDER BY ?fecha #Ordenados por fecha
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>premio</th>
#       <th>premioLabel</th>
#       <th>fecha</th>
#       <th>fechaLabel</th>
#       <th>obra</th>
#       <th>obraLabel</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td><a href="http://www.wikidata.org/entity/Q188914" target="_blank">http://www.wikidata.org/entity/Q188914</a></td>
#       <td>Hugo Award</td>
#       <td>1963-01-01T00:00:00Z</td>
#       <td>1963-01-01T00:00:00Z</td>
#       <td>None</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td><a href="http://www.wikidata.org/entity/Q6143927" target="_blank">http://www.wikidata.org/entity/Q6143927</a></td>
#       <td>James T. Grady-James H. Stack Award for Interp...</td>
#       <td>1965-01-01T00:00:00Z</td>
#       <td>1965-01-01T00:00:00Z</td>
#       <td>None</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td><a href="http://www.wikidata.org/entity/Q188914" target="_blank">http://www.wikidata.org/entity/Q188914</a></td>
#       <td>Hugo Award</td>
#       <td>1966-01-01T00:00:00Z</td>
#       <td>1966-01-01T00:00:00Z</td>
#       <td><a href="http://www.wikidata.org/entity/Q20899148" target="_blank">http://www.wikidata.org/entity/Q20899148</a></td>
#       <td>Foundation Trilogy</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <
td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td><a href="http://www.wikidata.org/entity/Q2576795" target="_blank">http://www.wikidata.org/entity/Q2576795</a></td>
#       <td>Locus Award for Best Science Fiction Novel</td>
#       <td>1983-01-01T00:00:00Z</td>
#       <td>1983-01-01T00:00:00Z</td>
#       <td><a href="http://www.wikidata.org/entity/Q932592" target="_blank">http://www.wikidata.org/entity/Q932592</a></td>
#       <td>Foundation’s Edge</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td><a href="http://www.wikidata.org/entity/Q255032" target="_blank">http://www.wikidata.org/entity/Q255032</a></td>
#       <td>Hugo Award for Best Novel</td>
#       <td>1983-01-01T00:00:00Z</td>
#       <td>1983-01-01T00:00:00Z</td>
#       <td><a href="http://www.wikidata.org/entity/Q932592" target="_blank">http://www.wikidata.org/entity/Q932592</a></td>
#       <td>Foundation’s Edge</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td><a href="http://www.wikidata.org/entity/Q19869310" target="_blank">http://www.wikidata.org/entity/Q19869310</a></td>
#       <td>Humanist of the Year</td>
#       <td>1984-01-01T00:00:00Z</td>
#       <td>1984-01-01T00:00:00Z</td>
#       <td>None</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td><a href="http://www.wikidata.org/entity/Q3404499" target="_blank">http://www.wikidata.org/entity/Q3404499</a></td>
#       <td>Cosmos 2000 Award</td>
#       <td>1985-01-01T00:00:00Z</td>
#       <td>1985-01-01T00:00:00Z</td>
#       <td><a href="http://www.wikidata.org/entity/Q440784" target="_blank">http://www.wikidata.org/entity/Q440784</a></td>
#       <td>The Robots of Dawn</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td><a href="http://www.wikidata.org/entity/Q17008985" target="_blank">http://www.wikidata.org/entity/Q17008985</a></td>
#       <td>Locus Award for Best Short Story</td>
#       <td>1987-01-01T00:00:00Z</td>
#       <td>1987-01-01T00:00:00Z</td>
#       <td><a href="http://www.wikidata.org/entity/Q583366" target="_blank">http://www.wikidata.org/entity/Q583366</a></td>
#       <td>Robot Dreams</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td><a href="http://www.wikidata.org/entity/Q901462" target="_blank">http://www.wikidata.org/entity/Q901462</a></td>
#       <td>Damon Knight Memorial Grand Master Award</td>
#       <td>1987-01-01T00:00:00Z</td>
#       <td>1987-01-01T00:00:00Z</td>
#       <td>None</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td><a href="http://www.wikidata.org/entity/Q1056265" target="_blank">http://www.wikidata.org/entity/Q1056265</a></td>
#       <td>Hugo Award for Best Novelette</td>
#       <td>1992-01-01T00:00:00Z</td>
#       <td>1992-01-01T00:00:00Z</td>
#       <td><a href="http://www.wikidata.org/entity/Q5578532" target="_blank">http://www.wikidata.org/entity/Q5578532</a></td>
#       <td>Gold</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td><a href="http://www.wikidata.org/entity/Q1056237" target="_blank">http://www.wikidata.org/entity/Q1056237</a></td>
#       <td>Hugo Award for Best Related Work</td>
#       <td>1995-01-01T00:00:00Z</td>
#       <td>1995-01-01T00:00:00Z</td>
#       <td>None</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td><a href="http://www.wikidata.org/entity/Q211632

# %% [markdown]
# ### Consulta 6
#
# Ahora queremos conocer todas las obras escritas por Asimov del tipo [obras literarias de ciencia ficción (Q3238422)](https://www.wikidata.org/wiki/Q3238422) y cualquiera de sus subgéneros. Los resultados se deben mostrar ordenados por nombre.
#
# No pasa nada si en el resultado aparecen mezclados novelas, relatos, colecciones...

# %%
# %%wdsparql
# SELECT ?item ?itemLabel ?genero ?generoLabel
# WHERE {
#   ?item wdt:P50 wd:Q34981.# ?item -> autor -> Isaac Asimov
td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td><a href="http://www.wikidata.org/entity/Q98141420" target="_blank">http://www.wikidata.org/entity/Q9

# %% [markdown]
# O si queremos que no se repitan obras con sus diferentes subgéneros:

# %%
# %%wdsparql
# SELECT ?item ?itemLabel
# WHERE {
#   ?item wdt:P50 wd:Q34981.
#   OPTIONAL {?item wdt:P136 ?genero.} # ?item -> genero -> ?genero (si lo hay)
#   OPTIONAL {?genero pq:P279 wd:Q3238422.} # ?genero -> subclase de -> literatura de ciencia ficcion (si tiene genero)
#   SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
# }
# GROUP BY ?item ?itemLabel
# ORDER BY ?itemLabel
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>item</th>
#       <th>itemLabel</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td><a href="http://www.wikidata.org/entity/Q104865083" target="_blank">http://www.wikidata.org/entity/Q104865083</a></td>
#       <td>Q104865083</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td><a href="http://www.wikidata.org/entity/Q104868766" target="_blank">http://www.wikidata.org/entity/Q104868766</a></td>
#       <td>Q104868766</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td><a href="http://www.wikidata.org/entity/Q104868864" target="_blank">http://www.wikidata.org/entity/Q104868864</a></td>
#       <td>Q104868864</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td><a href="http://www.wikidata.org/entity/Q104868972" target="_blank">http://www.wikidata.org/entity/Q104868972</a></td>
#       <td>Q104868972</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td><a href="http://www.wikidata.org/entity/Q104869051" target="_blank">http://www.wikidata.org/entity/Q104869051</a></td>
#       <td>Q104869051</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td><a href="http://www.wikidata.org/entity/Q12090866" target="_blank">http://www.wikidata.org/entity/Q12090866</a></td>
#       <td>Q12090866</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td><a href="http://www.wikidata.org/entity/Q16069681" target="_blank">http://www.wikidata.org/entity/Q16069681</a></td>
#       <td>Q16069681</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td><a href="http://www.wikidata.org/entity/Q16652396" target="_blank">http://www.wikidata.org/entity/Q16652396</a></td>
#       <td>Q16652396</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td><a href="http://www.wikidata.org/entity/Q17174405" target="_blank">http://www.wikidata.org/entity/Q17174405</a></td>
#       <td>Q17174405</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td><a href="http://www.wikidata.org/entity/Q25492175" target="_blank">http://www.wikidata.org/entity/Q25492175</a></td>
#       <td>Q25492175</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td><a href="http://www.wikidata.org/entity/Q28703445" target="_blank">http://www.wikidata.org/entity/Q28703445</a></td>
#       <td>Q28703445</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td><a href="http://www.wikidata.org/entity/Q3204873" target="_blank">http://www.wikidata.org/entity/Q3204873</a></td>
#       <td>Q3204873</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td><a href="http://www.wikidata.org/entity/Q3223257" target="_blank">http://www.wikidata.org/entity/Q3223257</a></td>
#       <td>Q3223257</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td><a href="http://www.wikidata.org/entity/Q3345921" target="_blank">http://www.wikidata.org/entity/Q3345921</a></td>
#       <td>Q3345921</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td><a href="http://www.wikidata.org/entity/Q3712510" target="_blank">http://www.wikidata.org/entity/Q3712510</a></td>
#       <td>Q3712510</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td><a href="http://www.wikidata.org/entity/Q3791230" target="_blank">http://www.wikidata.org/entity/Q3791230</a></td>
#       <td>Q3791230</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td><a href="http://www.wikidata.org/entity/Q3794320" target="_blank">http://www.wikidata.org/entity/Q3794320</a></td>
#       <td>Q3794320</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <
#       <td>Alexander the God</td>
#     </tr>
#     <tr>
#       <th>36</th>
#       <td><a href="http://www.wikidata.org/entity/Q4000825" target="_blank">http://www.wikidata.org/entity/Q4000825</a></td>
#       <td>All the Troubles of the World</td>
#     </tr>
#     <tr>
#       <th>37</th>
#       <td><a href="http://www.wikidata.org/entity/Q23307057" target="_blank">http://www.wikidata.org/entity/Q23307057</a></td>
#       <td>Androids, Time Machines and Blue Giraffes</td>
#     </tr>
#     <tr>
#       <th>38</th>
#       <td><a href="http://www.wikidata.org/entity/Q3618113" target="_blank">http://www.wikidata.org/entity/Q3618113</a></td>
#       <td>Anniversary</td>
#     </tr>
#     <tr>
#       <th>39</th>
#       <td><a href="http://www.wikidata.org/entity/Q28808642" targ

# %% [markdown]
# ### Consulta 7
#
# Vamos a volver a recuperar las mismas obras de la consulta anterior pero mostrando también la fecha de publicación de cada una. Las obras deben aparece aunque no tengan fecha de publicación asociada. En caso de que una obra tenga varias fechas de publicación, se mostrará sólo la más antigua. Los resultados deben aparecer en orden cronológico.
#
# Para calcular la fecha correcta tendrás que agrupar las respuestas por obra y aplicar una función de agregación sobre las fechas de publicación. Puede que [esto](https://www.wikidata.org/wiki/Wikidata:SPARQL_tutorial#Grouping) te resulte útil.

# %%
# %%wdsparql
# SELECT ?item ?itemLabel ?genero ?generoLabel (MIN(?fecha) as ?fecha_publ) # ?fecha_publ es el minimo de las ?fecha en cada grupo
# WHERE {
#   ?item wdt:P50 wd:Q34981.  # ?item -> autor -> Isaac Asimov
#   OPTIONAL {?item wdt:P136 ?genero.} # ?item -> genero -> ?genero (si lo hay)
#   OPTIONAL {?genero pq:P279 wd:Q3238422.} # ?genero -> subclase de -> literatura de ciencia ficcion (si tiene genero)
#   OPTIONAL {?item wdt:P577 ?fecha.}  # ?item -> fecha de publicacion -> ?fecha
#   SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
# }
# GROUP BY ?item ?itemLabel ?genero ?generoLabel  # Agrupamos por ?item y ?genero iguales
# ORDER BY ?itemLabel
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>item</th>
#       <th>itemLabel</th>
#       <th>genero</th>
#       <th>generoLabel</th>
#       <th>fecha_publ</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td><a href="http://www.wikidata.org/entity/Q104865083" target="_blank">http://www.wikidata.org/entity/Q104865083</a></td>
#       <td>Q104865083</td>
#       <td>None</td>
#       <td>None</td>
#       <td>1974-06-18T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td><a href="http://www.wikidata.org/entity/Q104868766" target="_blank">http://www.wikidata.org/entity/Q104868766</a></td>
#       <td>Q104868766</td>
#       <td><a href="http://www.wikidata.org/entity/Q24925" target="_blank">http://www.wikidata.org/entity/Q24925</a></td>
#       <td>science fiction</td>
#       <td>1973-03-16T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td><a href="http://www.wikidata.org/entity/Q104868864" target="_blank">http://www.wikidata.org/entity/Q104868864</a></td>
#       <td>Q104868864</td>
#       <td><a href="http://www.wikidata.org/entity/Q24925" target="_blank">http://www.wikidata.org/entity/Q24925</a></td>
#       <td>science fiction</td>
#       <td>1973-04-13T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <
td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td><a href="http://www.wikidata.org/entity/Q3791230" target="_blank">http://www.wikidata.org/entity/Q3791230</a></td>
#       <td>Q3791230</td>
#       <td><a href="http://www.wikidata.org/entity/Q105420" target="_blank">http://www.wikidata.org/entity/Q105420</a></td>
#       <td>anthology</td>
#       <td>1995-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td><a href="http://www.wikidata.org/entity/Q3791230" target="_blank">http://www.wikidata.org/entity/Q3791230</a></td>
#       <td>Q3791230</td>
#       <td><a href="http://www.wikidata.org/entity/Q1279564" target="_blank">http://www.wikidata.org/entity/Q1279564</a></td>
#       <td>short story collection</td>
#       <td>1995-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td><a href="http://www.wikidata.org/entity/Q3794320" target="_blank">http://www.wikidata.org/entity/Q3794320</a></td>
#       <td>Q3794320</td>
#       <td><a href="http://www.wikidata.org/entity/Q105420" target="_blank">http://www.wikidata.org/entity/Q105420</a></td>
#       <td>anthology</td>
#       <td>1994-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td><a href="http://www.wikidata.org/entity/Q3794320" target="_blank">http://www.wikidata.org/entity/Q3794320</a></td>
#       <td>Q3794320</td>
#       <td><a href="http://www.wikidata.org/entity/Q1279564" target="_blank">http://www.wikidata.org/entity/Q1279564</a></td>
#       <td>short story collection</td>
#       <td>1994-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td><a href="http://www.wikidata.org/entity/Q42723389" target="_blank">http://www.wikidata.org/entity/Q42723389</a></td>
#       <td>Q42723389</td>
#       <td><a href="http://www.wikidata.org/entity/Q24925" target="_blank">http://www.wikidata.org/entity/Q24925</a></td>
#       <td>science fiction</td>
#       <td>1985-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td><a href="http://www.wikidata.org/entity/Q42723496" target="_blank">http://www.wikidata.org/entity/Q42723496</a></td>
#       <td>Q42723496</td>
#       <td><a href="http://www.wikidata.org/entity/Q24925" target="_blank">http://www.wikidata.org/entity/Q24925</a></td>
#       <td>science fiction</td>
#       <td>1993-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td><a href="http://www.wikidata.org/entity/Q54826108" target="_blank">http://www.wikidata.org/entity/Q54826108</a></td>
#       <td>Q54826108</td>

# %% [markdown]
# ### Consulta 8
#
# Asimov es sin duda un autor prolífico. ¿Cuántas obras escribió a lo largo de su vida? Vamos a considerar sólo instancias directas de [literary work (Q7725634)](https://www.wikidata.org/wiki/Q7725634).

# %%
# %%wdsparql
# SELECT ?tipo ?tipoLabel (COUNT(?item) as ?numeroDeObras) #contamos el número de elementos en cada grupo
# WHERE {
#   ?item wdt:P50 wd:Q34981. # ?item -> autor -> Isaac Asimov
#   OPTIONAL {?item wdt:P31 ?tipo.} # ?item -> instancia de -> ?tipo
#   SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
# }
# GROUP BY ?tipo ?tipoLabel  #Agrupamos por ?tipo
# HAVING (?tipo = wd:Q7725634) #Restringimos el valor de ?tipo a obra literaria
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>tipo</th>
#       <th>tipoLabel</th>
#       <th>numeroDeObras</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td><a href="http://www.wikidata.org/entity/Q7725634" target="_blank">http://www.wikidata.org/entity/Q7725634</a></td>
#       <td>literary work</td>
#       <td>272</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ### Consulta 9
#
# De todas las obras que escribió a lo largo de su vida, queremos recuperar los nombres y fechas de publicación de aquellas escritas entre 1970 y 1980. Si alguna obra tiene varias fechas de publicación, se mostrará si alguna de ellas está dentro de ese periodo.
#
# Puede que [esto](https://www.wikidata.org/wiki/Wikidata:SPARQL_tutorial#FILTER) te resulte útil.

# %%
# %%wdsparql
# SELECT ?item ?itemLabel ?fecha
# WHERE {
#   ?item wdt:P50 wd:Q34981. # ?item -> autor -> Isaac Asimov
#   ?item wdt:P577 ?fecha.  # ?item -> fecha de pubicacion -> ?fecha
#   FILTER (YEAR(?fecha) > 1970 && YEAR(?fecha) < 1980) # Nos quedamos con los resultados en los que 1970 < ?fecha < 1980
#   SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
# }
# ORDER BY ?fecha
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>item</th>
#       <th>itemLabel</th>
#       <th>fecha</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td><a href="http://www.wikidata.org/entity/Q16932955" target="_blank">http://www.wikidata.org/entity/Q16932955</a></td>
#       <td>The Stars in their Courses</td>
#       <td>1971-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td><a href="http://www.wikidata.org/entity/Q16652396" target="_blank">http://www.wikidata.org/entity/Q16652396</a></td>
#       <td>Q16652396</td>
#       <td>1972-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td><a href="http://www.wikidata.org/entity/Q55172458" target="_blank">http://www.wikidata.org/entity/Q55172458</a></td>
#       <td>Q55172458</td>
#       <td>1972-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td><a href="http://www.wikidata.org/entity/Q98829663" target="_blank">http://www.wikidata.org/entity/Q98829663</a></td>
#       <td>asimov's guide to science</td>
#       <td>1972-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td><a href="http://www.wikidata.org/entity/Q6404541" target="_blank">http://www.wikidata.org/entity/Q6404541</a></td>
#       <td>Kid Stuff</td>
#       <td>1972-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td><a href="http://www.wikidata.org/entity/Q7677898" target="_blank">http://www.wikidata.org/entity/Q7677898</a></td>
#       <td>Take a Match</td>
#       <td>1972-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td><a href="http://www.wikidata.org/entity/Q7738024" target="_blank">http://www.wikidata.org/entity/Q7738024</a></td>
#       <td>The Greatest Asset</td>
#       <td>1972-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td><a href="http://www.wikidata.org/entity/Q7746627" target="_blank">http://www.wikidata.org/entity/Q7746627</a></td>
#       <td>The Left Hand of the Electron</td>
#       <td>1972-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td><a href="http://www.wikidata.org/entity/Q3345921" target="_blank">http://www.wikidata.org/entity/Q3345921</a></td>
#       <td>Q3345921</td>
#       <td>1972-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td><a href="http://www.wikidata.org/entity/Q389750" target="_blank">http://www.wikidata.org/entity/Q389750</a></td>
#       <td>The Gods Themselves</td>
#       <td>1972-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td><a href="http://www.wikidata.org/entity/Q831556" target="_blank">http://www.wikidata.org/entity/Q831556</a></td>
#       <td>Mirror Image</td>
#       <td>1972-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <
td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td><a href="http://www.wikidata.org/entity/Q104865083" target="_blank">http://www.wikidata.org/entity/Q104865083</a></td>
#       <td>Q104865083</td>
#       <td>1974-06-18T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td><a href="http://www.wikidata.org/entity/Q104863301" target="_blank">http://www.wikidata.org/entity/Q104863301</a></td>
#       <td>Flug durch die Sonne</td>
#       <td>1974-07-16T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td><a href="http://www.wikidata.org/entity/Q104869051" target="_blank">http://www.wikidata.org/entity/Q104869051</a></td>
#       <td>Q104869051</td>
#       <td>1974-10-08T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td><a href="http://www.wikidata.org/entity/Q16934361" target="_blank">http://www.wikidata.org/entity/Q16934361</a></td>
#       <td>Of Matters Great and Small</td>
#       <td>1975-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td><a href="http://www.wikidata.org/entity/Q6511577" target="_blank">http://www.wikidata.org/entity/Q6511577</a></td>
#       <td>Lecherous Limericks</td>
#       <td>1975-01-01T00:00:00Z</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td><a href="http://www.wikidata.org/entity/Q2621546" target="_blank">http://www.

# %% [markdown]
# ### Consulta 10
#
# ¿Qué otros escritores de ciencia ficción estudiaron en algún centro donde también estudió Asimov? Para cada uno de ellos muestra su nombre y fechas de nacimiento y defunción (si están disponibles) y el centro donde estudió. Muestra los resultados ordenados alfabéticamente por centro y luego por autor.

# %%
# %%wdsparql
# SELECT ?writer ?writerLabel ?school ?schoolLabel (MIN(?fechanac) as ?fechaNac) (MIN(?fechadef) as ?fechaDef)
# WHERE {
#   wd:Q34981 wdt:P69 ?school.            # Isaac Asimov -> educado en -> ?school
#   ?writer wdt:P69 ?school.              # ?writer -> educado en -> ?school
#   ?book wdt:P50 ?writer.                # ?book -> autor -> ?writer
#   ?book wdt:P136 ?genero.               # ?book -> género -> ?genero
#   ?genero wdt:P279* wd:Q3238422.        # ?genero -> (subclase de)* -> lieratura de ciencia ficcion
#   OPTIONAL{?writer wdt:P569 ?fechanac.} # ?writer -> fecha de nacimiento -> ?fechanac (si la hay)
#   OPTIONAL{?writer wdt:P570 ?fechadef.} # ?writer -> fecha de fallecimiento -> ?fechanac (si la hay)
#   FILTER(?writer != wd:Q34981).         # quitamos al propio Asimov
#   SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
# }
# GROUP BY ?writer ?writerLabel ?school ?schoolLabel # Agrupamos por autor y centro
# ORDER BY ?schoolLabel ?writerLabel      # Ordenamos por centro y luego por autor
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>writer</th>
#       <th>writerLabel</th>
#       <th>school</th>
#       <th>schoolLabel</th>
#       <th>fechaNac</th>
#       <th>fechaDef</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <